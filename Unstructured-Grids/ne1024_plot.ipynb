# %%
import os
import uxarray as ux
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from datetime import datetime
from cartopy.mpl.ticker import LatitudeFormatter, LongitudeFormatter
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1e57ee4d-9e8b-452c-a032-cad57bd18eba'>
#   <div id="ca9674fc-cbee-4b06-8f2f-051d53ed1c47" data-root-id="1e57ee4d-9e8b-452c-a032-cad57bd18eba" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
uxgrid_1 = ux.open_grid('/glade/work/nforcone/StormSPEED_ne1024/StormSPEED_ne1024.g')

# %%
lon_bounds = (0, 2.05)
lat_bounds = (0, 2.05)
uxgrid_subset = uxgrid_1.subset.bounding_box(lon_bounds, lat_bounds)

# %%
uxgrid_subset.plot()
# Out:
# :Path   [Longitude,Latitude]

# %%
uxgrid_ESMF = ux.open_grid('/glade/work/nforcone/StormSPEED_ne1024/StormSPEED_ne1024pg2_ESMF.nc')

# %%
uxgrid_ESMF_subset = uxgrid_ESMF.subset.bounding_box(lon_bounds, lat_bounds)

# %%
uxgrid_ESMF_subset.plot() * uxgrid_subset.plot()
# Out:
# :Overlay
#    .Path.I  :Path   [Longitude,Latitude]
#    .Path.II :Path   [Longitude,Latitude]

# %%
uxgrid_ESMF_working = ux.open_grid('/glade/work/jet/E3SM_inputdata/share/meshes/homme/ne1024pg2_scrip_20221011.mesh.nc')
uxgrid_ESMF_working_subset = uxgrid_ESMF_working.subset.bounding_box(lon_bounds, lat_bounds)

# %%
uxgrid_ESMF_subset.plot(color='red') * uxgrid_ESMF_working_subset.plot(color='black', alpha=0.2)
# Out:
# :Overlay
#    .Path.I  :Path   [Longitude,Latitude]
#    .Path.II :Path   [Longitude,Latitude]

# %%
uxgrid_diff = ux.open_grid('/glade/work/nforcone/diff.nc')

# %%
uxgrid_diff
# Out:
# <uxarray.Grid>
# Original Grid Type: Scrip
# Grid Dimensions:
#   * n_node: 36772427
#   * n_face: 25165824
#   * n_max_face_nodes: 4
# Grid Coordinates (Spherical):
#   * node_lon: (36772427,)
#   * node_lat: (36772427,)
#   * face_lon: (25165824,)
#   * face_lat: (25165824,)
# Grid Coordinates (Cartesian):
# Grid Connectivity Variables:
#   * face_node_connectivity: (25165824, 4)
# Grid Descriptor Variables:

# %%
uxgrid_diff.node_lon.min()
# Out:
# <xarray.DataArray 'node_lon' ()> Size: 8B
# array(-180.)

# %%
uxgrid_diff.node_lon.max()
# Out:
# <xarray.DataArray 'node_lon' ()> Size: 8B
# array(180.)
